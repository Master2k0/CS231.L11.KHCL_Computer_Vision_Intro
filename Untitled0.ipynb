# %% [markdown]
# <a href="https://colab.research.google.com/github/Master2k0/CS231.L11.KHCL_Computer_Vision_Intro/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 8.6MB/s
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/Master2k0/GANimation
# Out:
# Cloning into 'GANimation'...
# remote: Enumerating objects: 90, done.
# remote: Total 90 (delta 0), reused 0 (delta 0), pack-reused 90
# Unpacking objects: 100% (90/90), done.

# %%
# !ls

# %%
# %cd GANimation/
# Out:
# [Errno 2] No such file or directory: 'GANimation/'
# /content/GANimation
# checkpoints  launch   models	options    requirements.txt  test.py   utils
# data	     LICENSE  networks	README.md  sample_dataset    train.py

# %%
# !python data/prepare_au_annotations.py
# Out:
# Traceback (most recent call last):
#   File "data/prepare_au_annotations.py", line 39, in <module>
#     main()
#   File "data/prepare_au_annotations.py", line 27, in main
#     filepaths = glob.glob(os.path.join(args.input_aus_filesdir, '*.csv'))
#   File "/usr/lib/python3.6/posixpath.py", line 80, in join
#     a = os.fspath(a)
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
# !bash launch/run_train.sh
# Out:
# ------------ Options -------------
# D_adam_b1: 0.5
# D_adam_b2: 0.999
# G_adam_b1: 0.5
# G_adam_b2: 0.999
# aus_file: aus_openface.pkl
# batch_size: 25
# checkpoints_dir: ./checkpoints
# cond_nc: 17
# data_dir: /content/GANimation/sample_dataset
# dataset_mode: aus
# display_freq_s: 300
# do_saturate_mask: False
# gpu_ids: [0]
# image_size: 128
# images_folder: imgs
# is_train: True
# lambda_D_cond: 4000
# lambda_D_gp: 10
# lambda_D_prob: 1
# lambda_cyc: 10
# lambda_mask: 0.1
# lambda_mask_smooth: 1e-05
# load_epoch: 30
# lr_D: 0.0001
# lr_G: 0.0001
# model: ganimation
# n_threads_test: 1
# n_threads_train: 4
# name: experiment_1
# nepochs_decay: 10
# nepochs_no_decay: 20
# num_iters_validate: 1
# poses_g_sigma: 0.06
# print_freq_s: 60
# save_latest_freq_s: 3600
# serial_batches: False
# test_ids_file: test_ids.csv
# train_G_every_n_iterations: 5
# train_ids_file: train_ids.csv
# -------------- End ----------------
# ./checkpoints/experiment_1
# Dataset AusDataset was created
# ...

# %%
# !python test.py --input_path /content/GANimation/sample_dataset/imgs/N_0000000437_00540.jpg
# Out:
# ------------ Options -------------
# aus_file: aus_openface.pkl
# batch_size: 4
# checkpoints_dir: ./checkpoints
# cond_nc: 17
# data_dir: None
# dataset_mode: aus
# do_saturate_mask: False
# gpu_ids: [0]
# image_size: 128
# images_folder: imgs
# input_path: /content/GANimation/sample_dataset/imgs/N_0000000437_00540.jpg
# is_train: False
# load_epoch: 30
# model: ganimation
# n_threads_test: 1
# name: experiment_1
# output_dir: ./output
# serial_batches: False
# test_ids_file: test_ids.csv
# train_ids_file: train_ids.csv
# -------------- End ----------------
# ./checkpoints/experiment_1
# Network generator_wasserstein_gan was created
# Network discriminator_wasserstein_gan was created
# loaded net: ./checkpoints/experiment_1/net_epoch_30_id_G.pth
# Model GANimation was created
# /content/GANimation/models/ganimation.py:106: UserWarning: This overload of cuda is deprecated:
# 	cuda(torch.device device, bool async, *, torch.memory_format memory_format)
# ...

# %%
# !zip -r /content/file.zip /content/GANimation
from google.colab import files
files.download("/content/GANimation.zip")
# Out:
#   adding: content/GANimation/ (stored 0%)
#   adding: content/GANimation/data/ (stored 0%)
#   adding: content/GANimation/data/__pycache__/ (stored 0%)
#   adding: content/GANimation/data/__pycache__/custom_dataset_data_loader.cpython-36.pyc (deflated 48%)
#   adding: content/GANimation/data/__pycache__/__init__.cpython-36.pyc (deflated 23%)
#   adding: content/GANimation/data/__pycache__/dataset.cpython-36.pyc (deflated 50%)
#   adding: content/GANimation/data/__pycache__/dataset_aus.cpython-36.pyc (deflated 47%)
#   adding: content/GANimation/data/dataset_aus.py (deflated 71%)
#   adding: content/GANimation/data/custom_dataset_data_loader.py (deflated 63%)
#   adding: content/GANimation/data/prepare_au_annotations.py (deflated 52%)
#   adding: content/GANimation/data/__init__.py (stored 0%)
#   adding: content/GANimation/data/dataset.py (deflated 63%)
#   adding: content/GANimation/requirements.txt (deflated 6%)
#   adding: content/GANimation/LICENSE (deflated 66%)
# ...
